# %% [markdown]
# # <span style="font-family: Verdana;color:#0DA2B5;">By Shynitha Muthyam</span>

# %% [markdown]
# # <span style="font-family: Verdana;color:#3E2488;">The Sparks Foundation</span>

# %% [markdown]
# # Data Science & Business Analytics Internship

# %% [markdown]
# ## Task-6:Prediction using Decision Tree Algorithm(Intermediate-Level)

# %%
#importing the  libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#read the dataset
data=pd.read_csv(r"C:\Users\shynitha\Desktop\TheSparksFoundation\iris.csv",index_col='Id')

# %%
data.shape
# Out:
# (150, 5)

# %%
data.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.dropna()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# No null values in the dataset

# %%
data.shape
# Out:
# (150, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %% [markdown]
# ## <span style="color:#3E2488;">Pairwise plotting,to observe species classes,with the variation of other features</span>

# %%
sns.set_style("ticks")
sns.pairplot(data,hue = 'Species',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %% [markdown]
# ### Splitting the data set

# %%
x=data.drop('Species',axis=1)

# %%
y=data['Species']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler  
s = StandardScaler()  
s.fit(x_train)
 
x_train = s.transform(x_train)  
x_test = s.transform(x_test)

# %% [markdown]
# ### Building the model

# %%
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Calculating the accuracy of the model
clf.score(x_train,y_train)
# Out:
# 1.0

# %%
clf.score(x_test,y_test)
# Out:
# 0.9777777777777777

# %%
y_pred=clf.predict(x_test)
y_pred
# Out:
# array(['Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica'],
#       dtype=object)

# %% [markdown]
# ## We can also use gini criteria

# %%
clf_t= DecisionTreeClassifier(criterion = "gini", random_state = 100,max_depth=3, min_samples_leaf=5)

# %%
clf_t.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=5, random_state=100)

# %%
clf_t.score(x_train,y_train)
# Out:
# 0.9523809523809523

# %%
clf_t.score(x_test,y_test)
# Out:
# 0.9555555555555556

# %% [markdown]
# ## <span style="font-family: Arial;color:#6B4171;">Predicting the species with SepalLengthCm-4.8,SepalWidthCm-2.8,PetalLengthCm-5.1,PetalWidthCm -1.5 </span>

# %%
#Predicting without using gini criteria
a=clf.predict([[4.8,2.8,5.1,1.5]])
print("The predicted class is {}".format(a[0]))
# Out:
# The predicted class is Iris-virginica

# %%
#Predicting with using gini criteria
a1=clf_t.predict([[4.8,2.8,5.1,1.5]])
print("The predicted class is {}".format(a1[0]))
# Out:
# The predicted class is Iris-virginica

# %% [markdown]
#  # <span style="font-family: Arial;color: purple;">Visualizing the tree</span> .

# %%
import io
from io import StringIO 
import pydotplus
import pydot

# %%
from sklearn import tree
from sklearn.tree import plot_tree
#f=data.drop(['Species'],axis=1).columns
#c=data['Species'].unique()
plt.figure(figsize=(15,25),frameon=True,facecolor='#EBEDB5',edgecolor='#E11111')
tree.plot_tree(clf,feature_names=x.columns,class_names=y.unique(),rounded=True,filled=True)
# Out:
# [Text(334.8, 1245.75, 'PetalWidthCm <= -0.529\ngini = 0.666\nsamples = 105\nvalue = [37, 34, 34]\nclass = Iris-setosa'),
#  Text(251.10000000000002, 1019.25, 'gini = 0.0\nsamples = 37\nvalue = [37, 0, 0]\nclass = Iris-setosa'),
#  Text(418.5, 1019.25, 'PetalLengthCm <= 0.66\ngini = 0.5\nsamples = 68\nvalue = [0, 34, 34]\nclass = Iris-versicolor'),
#  Text(167.4, 792.75, 'PetalWidthCm <= 0.66\ngini = 0.114\nsamples = 33\nvalue = [0, 31, 2]\nclass = Iris-versicolor'),
#  Text(83.7, 566.25, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]\nclass = Iris-versicolor'),
#  Text(251.10000000000002, 566.25, 'SepalWidthCm <= 0.159\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = Iris-virginica'),
#  Text(167.4, 339.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = Iris-virginica'),
#  Text(334.8, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Iris-versicolor'),
# ...

# %% [markdown]
# # <span style="font-family: Arial;color:#6B4171;">THANK YOU</span>
